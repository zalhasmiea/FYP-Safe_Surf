# %%
import matplotlib.pyplot as plt

# Data
labels = ['Legitimate', 'Phishing']
sizes = [80, 20]
colors = ['#c6f6d5', '#feb2b2']

# Create a new style: donut-style pie chart with enhanced design
fig, ax = plt.subplots()

# Create a donut chart
wedges, texts, autotexts = ax.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%',
    startangle=140,
    colors=colors,
    wedgeprops={'linewidth': 1.5, 'edgecolor': 'white'},
    textprops={'color': '#2d3748', 'fontsize': 12},
    pctdistance=0.75
)

# Draw center circle for donut effect
centre_circle = plt.Circle((0, 0), 0.50, fc='white')
fig.gca().add_artist(centre_circle)

# Set title and layout
ax.set_title('URL Classification Breakdown', color='#2d3748', fontsize=16, pad=20)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Set default font to Poppins and bold for all text in the plot
rcParams['font.family'] = 'Poppins'
rcParams['font.weight'] = 'bold'

# Data
months = ['April', 'May', 'June']
total_scans = [5000, 5400, 5587]
malicious_counts = [900, 1050, 1247]
legitimate_counts = [t - m for t, m in zip(total_scans, malicious_counts)]

# Plot
fig, ax = plt.subplots(figsize=(8, 6), facecolor='none')

# Bars
ax.bar(months, legitimate_counts, label='Legitimate', color='#c6f6d5')
ax.bar(months, malicious_counts, bottom=legitimate_counts, label='Phishing', color='#feb2b2')

# Remove axis spines
for spine in ax.spines.values():
    spine.set_visible(False)

# Styling
# Remove y-axis label as before
# ax.set_ylabel('URLs Scanned')

ax.legend(prop={'weight':'bold'})  # Legend text bold
ax.grid(False)
ax.set_facecolor('none')  # Transparent background
fig.patch.set_alpha(0)    # Transparent figure background
ax.set_title('', fontweight='bold')  # Title bold (empty in your case)

plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# ...

# %%
from ucimlrepo import fetch_ucirepo

# Fetch dataset
phishing_websites = fetch_ucirepo(id=327)

# Print dataset metadata
print(phishing_websites.metadata)

# Print variable information (including the target variable)
print(phishing_websites.variables['Result'])
# Out:
# {'uci_id': 327, 'name': 'Phishing Websites', 'repository_url': 'https://archive.ics.uci.edu/dataset/327/phishing+websites', 'data_url': 'https://archive.ics.uci.edu/static/public/327/data.csv', 'abstract': 'This dataset collected mainly from: PhishTank archive, MillerSmiles archive, Googleâ€™s searching operators.', 'area': 'Computer Science', 'tasks': ['Classification'], 'characteristics': ['Tabular'], 'num_instances': 11055, 'num_features': 30, 'feature_types': ['Integer'], 'demographics': [], 'target_col': ['result'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2012, 'last_updated': 'Tue Mar 05 2024', 'dataset_doi': '10.24432/C51W2X', 'creators': ['Rami Mohammad', 'Lee McCluskey'], 'intro_paper': {'ID': 396, 'type': 'NATIVE', 'title': 'An assessment of features related to phishing websites using an automated technique', 'authors': 'R. Mohammad, F. Thabtah, L. Mccluskey', 'venue': 'International Conference for Internet T
# ...
